# %% [markdown]
# # Introduction to EDA

# %% [markdown]
# ## import libs

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import os
os.chdir('C:\\Users\\arbil\\OneDrive\\Desktop\\baruch_ds_apr_18\\ipnyb\\data')
os.getcwd()
# Out:
# 'C:\\Users\\arbil\\OneDrive\\Desktop\\baruch_ds_apr_18\\ipnyb\\data'

# %% [markdown]
# ## reading data with pandas

# %% [markdown]
# ### data fields
#
#     RM: average number of rooms per dwelling
#     LSTAT: percentage of population considered lower status
#     PTRATIO: pupil-teacher ratio by town
#     MEDV: median value of owner-occupied homes

# %%
# Read in the DataFrame

df = pd.read_csv('housing.csv')

# %% [markdown]
# ## data inspection

# %%
# top 
df.head()
# Out:
#       RM  LSTAT  PTRATIO      MEDV
# 0  6.575   4.98     15.3  504000.0
# 1  6.421   9.14     17.8  453600.0
# 2  7.185   4.03     17.8  728700.0
# 3  6.998   2.94     18.7  701400.0
# 4  7.147   5.33     18.7  760200.0

# %% [markdown]
# ##  summary statistics with pandas

# %%
df.describe()
# Out:
#                RM       LSTAT     PTRATIO          MEDV
# count  489.000000  489.000000  489.000000  4.890000e+02
# mean     6.240288   12.939632   18.516564  4.543429e+05
# std      0.643650    7.081990    2.111268  1.653403e+05
# min      3.561000    1.980000   12.600000  1.050000e+05
# 25%      5.880000    7.370000   17.400000  3.507000e+05
# 50%      6.185000   11.690000   19.100000  4.389000e+05
# 75%      6.575000   17.120000   20.200000  5.187000e+05
# max      8.398000   37.970000   22.000000  1.024800e+06

# %% [markdown]
# ## histograms with matplotlib

# %%
# histogram plotting function
def print_hist(col_name):
    df[col_name].plot.hist()
    plt.title(col_name)
    plt.show()
    plt.clf()

# plot all columns in dataframe
for col_name in df.columns:
    print_hist(col_name)

# %% [markdown]
# ## distribution density plots with seaborn
#
# <a href="https://mathisonian.github.io/kde/">KDE = Kernel Density Estimate</a>

# %%
# density plotting function
def print_dist(col_name):    
    sns.distplot(df[col_name],hist=False, kde_kws={'shade':True})
    plt.show()
    plt.clf()

# plot all columns in dataframe
for col_name in df.columns:
    print_dist(col_name)

# %% [markdown]
# ## boxplot with seaborn

# %%
# boxplot plotting function
def print_box(col_name):    
    sns.boxplot(df[col_name])
    plt.show()
    plt.clf()

# plot all columns in dataframe
for col_name in df.columns:
    print_box(col_name)

# %% [markdown]
# ## swarmplot with seaborn

# %%
# # swarmplot plotting function
# def print_swarm(col_name):    
#     sns.swarmplot(df[col_name])
#     plt.show()
#     plt.clf()

# # plot all columns in dataframe
# for col_name in df.columns:
#     print_swarm(col_name)

# %% [markdown]
# ## pair plots with seaborn

# %%
g = sns.pairplot(df)

# %% [markdown]
# ## correlation with seaborn

# %%
sns.jointplot(x="MEDV",
        y="RM",
        kind='reg',
        data=df)

plt.show()
plt.clf()
# Out:
# C:\Users\arbil\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\arbil\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.jointplot(x="MEDV",
        y="LSTAT",
        kind='reg',
        data=df)

plt.show()
plt.clf()
# Out:
# C:\Users\arbil\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\arbil\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.jointplot(x="RM",
        y="LSTAT",
        kind='reg',
        data=df)

plt.show()
plt.clf()
# Out:
# C:\Users\arbil\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\arbil\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# ### -- code complete --
